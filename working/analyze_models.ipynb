# %% [markdown]
# ## Imports

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
import matplotlib.pyplot as plt
import pandas as pd
import json
from glob import glob
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option("display.max_rows", None)
# Out:
# <style>.container { width:80% !important; }</style>

# %%
mdl_df = pd.read_csv("../models/results.csv")
mdl_df
# Out:
#     Unnamed: 0  version  folds  img_size  resize  batch_size  epochs  \
# 0            0        6      1       256       1          20      30
# 1            1       13      4       256       1          32      40
# 2            2       14      4       256       4          32      40
# 3            3       22      1       256       4          64       1
# 4            4       24      1       256       4          32      20
# 5            5       25      1       256       4          32      20
# 6            6       17      4       256       4          16      30
# 7            7       27      1       256       4          32      20
# 8            8       31      1       256       4          32      20
# 9            9       26      1       256       4          32     100
# 10          10       36      1       256       4          40      20
# 11          11       37      1       256       4          40      20
# 12          12       38      1       256       4          32     100
# 13          13       40      1       256       4          16      50
# 14          14       41      1       256       4         128     100
# 15          15       42      1       256       4         128      50
# 16          16       45      1       256       4          64      50
# 17          17       47      1       256       4         128     100
# 18          18       49      1       256       4          40    1000
# 19          19       48      1       256       4          32     100
# 20          20       50      1       256       4          64    1000
# 21          21       55      1       256       4          32    1000
# 22          22       51      1       256       4          32     100
# 23          23       57      1       256       4          32    1000
# 24          24       59      1       256       4          32    1000
# 25          25       61      1       256       4         128    1000
# 26          26       65      1       256       4          32    1000
# 27          27       70      1       256       4          64    1000
# 28          28       72      1       256       4          32    1000
# 29          29       83      1       256       4          32    1000
# 30          30       84      1       256       4          32    1000
# 31          31       71      1       256       4          64    1000
# 32          32       89      1       256       4         128    1000
# 33          33       85      1       256       4          32    1000
# 34          34       94      1       256       4         128    1000
# 35          35       95      1       256       4         128      20
# 36          36       96      5       256       4         128      20
# 37          37       98      1       256       4         128      20
# 38          38       99      1       256       4         128      20
# 39          39      100      1       256       4         128      20
# 40          40      106      1       256       4          32    1000
# 41          41      105      1       256       4          32    1000
# 42          42      110      5       256       4         128    1000
# 43          43      113      2       256       4          32    1000
# 44          44      114      1       256       4          16    1000
# 45          45      115      1       256       4          32    1000
# 46          46      112      4       256       4          64    1000
# 47          47      116      1       256       4          64    1000
# 48          48      117      1       256       4          64    1000
# 49          49      127      1       512       4           8    1000
# 50          50      128      1       512       4          32    1000
# 51          51      129      1       512       4          32    1000
# 52          52      131      0       512       4          32    1000
# 53          53      132      0       512       4           8    1000
# 54          54      145      1       512       4           8    1000
# 55          55      138      4       256       4          24    1000
# 56          56      147      1       256       4          32    1000
# 57          57      146      1       256       4          32    1000
# 58          58      147      1       256       4          32      20
# 59          59      153      1       256       4         128    1000
# 60          60      156      1       256       4         128    1000
# 61          61      158      1       256       4          32      20
# 62          62      161      1       256       4         128    1000
# 63          63      163      1       256       4          32    1000
# 64          64      162      1       256       4          32    1000
#
#     patience        backbone              loss  mirror umodel  bce_weight  \
# 0         20  efficientnetb7          bce_dice   False   unet         1.0
# 1         20  efficientnetb7          bce_dice   False   unet         1.0
# 2         20  efficientnetb7          bce_dice   False   unet         1.0
# 3         20  efficientnetb0          bce_dice   False   unet         1.0
# 4         20  efficientnetb0          bce_dice   False   unet         1.0
# 5         20  efficientnetb0          bce_dice   False   unet         1.0
# 6         20  efficientnetb5          bce_dice   False   unet         1.0
# 7         10  efficientnetb0          bce_dice   False   unet         1.0
# 8         10  efficientnetb0          bce_dice   False   unet         1.0
# 9         10  efficientnetb0          bce_dice   False   unet         1.0
# 10        10  efficientnetb0          bce_dice   False   unet         1.0
# 11        20  efficientnetb0          bce_dice   False   unet         1.0
# 12        10  efficientnetb7          bce_dice   False   unet         1.0
# 13        20  efficientnetb5          bce_dice   False   unet         1.0
# 14        20  efficientnetb0          bce_dice   False   unet         1.0
# 15        20  efficientnetb0          bce_dice   False   unet         1.0
# 16        20     inceptionv3          bce_dice   False   unet         1.0
# 17        20  efficientnetb0          bce_dice   False   link         1.0
# 18        20  efficientnetb1  bce_jaccard_loss   False   link         1.0
# 19        20  efficientnetb7          bce_dice   False   unet         1.0
# 20        20     inceptionv3  bce_jaccard_loss   False   link         1.0
# 21        20        resnet50  bce_jaccard_loss   False   link         1.0
# 22        20  efficientnetb7  bce_jaccard_loss   False   link         1.0
# 23        20        resnet50  bce_jaccard_loss   False   link         1.0
# 24        20        resnet50  bce_jaccard_loss   False   link         1.0
# 25        20       resnext50  bce_jaccard_loss   False   link         1.0
# 26        20  efficientnetb0  bce_jaccard_loss   False    fpn         1.0
# 27        20     densenet201  bce_jaccard_loss   False   link         1.0
# 28        20     densenet121  bce_jaccard_loss   False   link         1.0
# 29        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 30        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 31        20      resnext101  bce_jaccard_loss   False   link         1.0
# 32        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 33        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 34        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 35        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 36        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 37        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 38        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 39        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 40        20  efficientnetb7  bce_jaccard_loss   False   link         1.0
# 41        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 42        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 43        20     densenet201  bce_jaccard_loss   False   link         1.0
# 44        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 45        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 46        20      resnext101  bce_jaccard_loss   False   link         1.0
# 47        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 48        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 49        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 50        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 51        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 52        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 53        20  efficientnetb2  bce_jaccard_loss   False   link         1.0
# 54        20  efficientnetb7  bce_jaccard_loss   False   unet         1.0
# 55        20  efficientnetb0  bce_jaccard_loss   False   unet         1.0
# 56        20  efficientnetb2  bce_jaccard_loss   False   link         1.0
# 57        20  efficientnetb7  bce_jaccard_loss   False   link         1.0
# 58        20  efficientnetb7  bce_jaccard_loss   False   link         1.0
# 59        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 60        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 61        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 62        20  efficientnetb0  bce_jaccard_loss   False   link         1.0
# 63        30  efficientnetb2  bce_jaccard_loss   False   link         1.0
# 64        30  efficientnetb7  bce_jaccard_loss   False   link         1.0
#
#     shift  pseudo      lr  best_epoch  best_loss  best_dice_coef  split  seed  \
# 0    True     NaN  0.0002        25.0   0.004156        0.894248    NaN   NaN
# 1    True     NaN  0.0002         NaN        NaN             NaN  kfold   NaN
# 2    True     NaN  0.0010         NaN        NaN             NaN  kfold   NaN
# 3    True     NaN  0.0001         NaN        NaN             NaN   dont   NaN
# 4    True     NaN  0.0001         NaN        NaN             NaN   dont  42.0
# 5    True     NaN  0.0001         NaN        NaN             NaN   dont  42.0
# 6    True     NaN  0.0002         NaN        NaN             NaN  kfold   NaN
# 7    True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 8    True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 9    True     NaN  0.0001         NaN        NaN             NaN   dont  42.0
# 10   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 11   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 12   True     NaN  0.0001         NaN        NaN             NaN  kfold  69.0
# 13   True     NaN  0.0001         NaN        NaN             NaN  kfold  69.0
# 14   True     NaN  0.0001         NaN        NaN             NaN  kfold  69.0
# 15   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 16   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 17   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 18   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 19   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 20   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 21   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 22   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 23   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 24   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 25   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 26   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 27   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 28   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 29   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 30   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 31   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 32   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 33   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 34   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 35   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 36   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 37   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 38   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 39   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 40   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 41   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 42   True     NaN  0.0001         NaN        NaN             NaN  kfold  69.0
# 43   True     NaN  0.0001         NaN        NaN             NaN  kfold  69.0
# 44   True     NaN  0.0001         NaN        NaN             NaN   dont  69.0
# 45   True     NaN  0.0005         NaN        NaN             NaN   dont  69.0
# 46   True     NaN  0.0001         NaN        NaN             NaN  kfold  69.0
# 47   True     NaN  0.0005         NaN        NaN             NaN   dont  69.0
# 48   True     NaN  0.0010         NaN        NaN             NaN   dont  69.0
# 49   True     NaN  0.0003         NaN        NaN             NaN  kfold  69.0
# 50   True     NaN  0.0005         NaN        NaN             NaN   dont  69.0
# 51   True     NaN  0.0005         NaN        NaN             NaN   dont  69.0
# 52   True     NaN  0.0005         NaN        NaN             NaN   dont  69.0
# 53   True     NaN  0.0003         NaN        NaN             NaN  kfold  69.0
# 54   True     NaN  0.0002         NaN        NaN             NaN   dont  69.0
# 55   True     NaN  0.0005         NaN        NaN             NaN  strat  69.0
# 56   True     NaN  0.0003         NaN        NaN             NaN   dont  69.0
# 57   True     NaN  0.0004         NaN        NaN             NaN   dont  69.0
# 58   True   146.0  0.0004         NaN        NaN             NaN   dont  69.0
# 59   True     NaN  0.0005         NaN        NaN             NaN   dont  69.0
# 60   True     NaN  0.0010         NaN        NaN             NaN   dont  69.0
# 61   True     NaN  0.0003         NaN        NaN             NaN   dont  69.0
# 62   True     NaN  0.0010         NaN        NaN             NaN   dont  69.0
# 63   True     1.0  0.0005         NaN        NaN             NaN   dont  69.0
# 64   True     1.0  0.0005         NaN        NaN             NaN   dont  69.0
#
#     bavg_epoch  bavg_loss  bavg_dice_coef                       dice_by_folds  \
# 0          NaN        NaN             NaN                                 NaN
# 1    15.500000   0.236562        0.454637         0.6554 0.4974 0.5797 0.0861
# 2    24.666667        NaN             NaN                   nan 0.2318 0.3154
# 3     0.000000   0.516637        0.077527                              0.0775
# 4    15.000000   0.027320        0.777308                              0.7773
# 5    19.000000   0.019676        0.884997                              0.8850
# 6    13.000000   0.083721        0.637541         0.8200 0.8174 0.1290 0.7837
# 7    16.000000   0.033654        0.662921                              0.6629
# 8    11.000000   0.073768        0.667674                              0.6677
# 9    46.000000   0.025203        0.899880                              0.8999
# 10         NaN        NaN             NaN                                 NaN
# 11   19.000000   0.018537        0.875044                              0.8750
# 12   52.000000   0.017930        0.922658                              0.9227
# 13   47.000000   0.020173        0.885169                              0.8852
# 14         NaN        NaN             NaN                                 NaN
# 15   49.000000   0.013263        0.874816                              0.8748
# 16   44.000000   0.012161        0.901803                              0.9018
# 17   97.000000   0.012695        0.911277                              0.9113
# 18   91.000000   0.011367        0.910720                              0.9107
# 19   58.000000   0.009887        0.912130                              0.9121
# 20   92.000000   0.012949        0.902273                              0.9023
# 21         NaN        NaN             NaN                                 NaN
# 22   90.000000   0.009965        0.912303                              0.9123
# 23   58.000000   0.011465        0.895391                              0.8954
# 24   78.000000   0.011445        0.899069                              0.8991
# 25  109.000000   0.011597        0.922328                              0.9223
# 26   58.000000   0.011716        0.898226                              0.8982
# 27   82.000000   0.012208        0.920322                              0.9203
# 28   78.000000   0.012159        0.905066                              0.9051
# 29         NaN        NaN             NaN                                 NaN
# 30  100.000000   0.012303        0.892455                              0.8925
# 31  156.000000   0.011064        0.927117                              0.9271
# 32  202.000000   0.018168        0.846635                              0.8466
# 33   78.000000   0.012189        0.892328                              0.8923
# 34  134.000000   0.012813        0.909781                              0.9098
# 35   19.000000   0.029001        0.661627                              0.6616
# 36   19.000000   0.029001        0.661627                              0.6616
# 37   19.000000   0.031102        0.650727                              0.6507
# 38   19.000000   0.029677        0.666057                              0.6661
# 39   19.000000   0.029138        0.668435                              0.6684
# 40         NaN        NaN             NaN                                 NaN
# 41         NaN        NaN             NaN                                 NaN
# 42  129.400000   0.012331        0.905881  0.9072 0.9095 0.9040 0.8955 0.9132
# 43   75.500000   0.010926        0.890535                       0.9063 0.8748
# 44   54.000000   0.012868        0.842104                              0.8421
# 45   56.000000   0.011784        0.892494                              0.8925
# 46   86.250000        NaN             NaN               nan nan 0.9224 0.9285
# 47   48.000000   0.012210        0.908255                              0.9083
# 48   59.000000   0.011454        0.907534                              0.9075
# 49   80.000000   0.009831        0.854144                              0.8541
# 50  104.000000   0.009087        0.924909                              0.9249
# 51   87.000000   0.008998        0.917775                              0.9178
# 52         NaN        NaN             NaN                                 NaN
# 53         NaN        NaN             NaN                                 NaN
# 54   70.000000   0.008068        0.864604                              0.8646
# 55   46.750000   0.011161        0.863800         0.8833 0.8765 0.8503 0.8450
# 56   70.000000   0.011610        0.899094                              0.8991
# 57   62.000000   0.009849        0.908954                              0.9090
# 58   10.000000   0.007323        0.910158                              0.9102
# 59  107.000000   0.012169        0.913624                              0.9136
# 60   96.000000   0.012491        0.912450                              0.9125
# 61   18.000000   0.013592        0.834838                              0.8348
# 62   96.000000   0.022154        0.917613                              0.9176
# 63   51.000000   0.017386        0.911593                              0.9116
# 64   69.000000   0.017459        0.917833                              0.9178
#
#    mixed_precision aughard   norm    bnw  weights triple reduce_dims   ext
# 0              NaN     NaN    NaN    NaN      NaN    NaN         NaN   NaN
# 1              NaN     NaN    NaN    NaN      NaN    NaN         NaN   NaN
# 2              NaN     NaN    NaN    NaN      NaN    NaN         NaN   NaN
# 3              NaN     NaN    NaN    NaN      NaN    NaN         NaN   NaN
# 4              NaN     NaN    NaN    NaN      NaN    NaN         NaN   NaN
# 5            False     NaN    NaN    NaN      NaN    NaN         NaN   NaN
# 6              NaN     NaN    NaN    NaN      NaN    NaN         NaN   NaN
# 7             True     NaN    NaN    NaN      NaN    NaN         NaN   NaN
# 8             True     NaN    NaN    NaN      NaN    NaN         NaN   NaN
# 9            False     NaN    NaN    NaN      NaN    NaN         NaN   NaN
# 10            True   False    NaN    NaN      NaN    NaN         NaN   NaN
# 11            True   False    NaN    NaN      NaN    NaN         NaN   NaN
# 12            True   False    NaN    NaN      NaN    NaN         NaN   NaN
# 13            True   False    NaN    NaN      NaN    NaN         NaN   NaN
# 14            True   False    NaN    NaN      NaN    NaN         NaN   NaN
# 15            True    True    NaN    NaN      NaN    NaN         NaN   NaN
# 16            True    True    NaN    NaN      NaN    NaN         NaN   NaN
# 17            True    True    NaN    NaN      NaN    NaN         NaN   NaN
# 18            True    True    NaN    NaN      NaN    NaN         NaN   NaN
# 19            True    True    NaN    NaN      NaN    NaN         NaN   NaN
# 20            True    True    NaN    NaN      NaN    NaN         NaN   NaN
# 21            True    True    NaN    NaN      NaN    NaN         NaN   NaN
# 22            True    True    NaN    NaN      NaN    NaN         NaN   NaN
# 23            True    True    NaN    NaN      NaN    NaN         NaN   NaN
# 24            True    True    NaN    NaN      NaN    NaN         NaN   NaN
# 25            True    True    NaN    NaN      NaN    NaN         NaN   NaN
# 26            True    True    NaN    NaN      NaN    NaN         NaN   NaN
# 27            True    True    NaN    NaN      NaN    NaN         NaN   NaN
# 28            True    True    NaN    NaN      NaN    NaN         NaN   NaN
# 29            True    True  False  False      NaN    NaN         NaN   NaN
# 30            True    True   True   True      NaN    NaN         NaN   NaN
# 31            True    True    NaN    NaN      NaN    NaN         NaN   NaN
# 32            True    True   True   True      NaN    NaN         NaN   NaN
# 33            True    True   True   True      NaN    NaN         NaN   NaN
# 34            True    True   True   True      NaN   True         NaN   NaN
# 35            True    True   True   True      NaN   True         NaN   NaN
# 36            True    True   True   True      NaN   True        True   NaN
# 37            True    True   True   True      NaN   True       False   NaN
# 38            True    True  False  False      NaN  False       False   NaN
# 39            True    True  False  False      NaN  False       False   NaN
# 40            True    True   True   True      NaN   True        True   NaN
# 41            True    True   True   True      NaN   True        True   NaN
# 42            True    True   True   True      NaN   True       False   NaN
# 43            True    True   True   True      NaN   True       False   NaN
# 44            True    True   True   True      NaN   True       False   NaN
# 45            True    True   True   True      NaN   True       False   NaN
# 46            True    True   True   True      NaN   True       False   NaN
# 47            True    True   True   True      NaN   True       False   NaN
# 48            True    True   True   True      NaN   True       False   NaN
# 49            True    True   True   True      NaN   True        True   NaN
# 50            True    True   True   True      NaN   True       False   NaN
# 51            True    True   True   True      NaN   True       False   NaN
# 52            True    True   True   True      NaN   True        True   NaN
# 53            True    True   True   True      NaN   True        True   NaN
# 54            True    True   True   True      NaN   True       False   NaN
# 55            True    True  False  False      NaN  False       False   NaN
# 56            True    True   True   True      NaN   True        True   NaN
# 57            True    True   True   True      NaN   True        True   NaN
# 58            True    True   True   True      NaN   True        True   NaN
# 59            True    True   True   True      NaN   True       False   NaN
# 60            True    True   True   True      NaN   True       False   NaN
# 61            True    True   True   True      NaN   True        True  True
# 62            True    True    NaN   True      NaN    NaN        True  True
# 63            True    True    NaN   True      NaN    NaN        True  True
# 64            True    True    NaN   True      NaN    NaN        True  True

# %% [markdown]
# ## Plotfunction

# %%
def plot_vers(VERS):
    fig, axes = plt.subplots(figsize = (32, 32), nrows = 2, ncols = 2)
    for VER in VERS: 
        hist_paths = glob(f"../models/models_v{VER:03}/history_*")
        i = 0
        for hist_path in hist_paths:
            history = json.load(open(hist_path))
        
            dice_coef = np.array(history["dice_coef"]).astype(np.float32)
            val_dice_coef = np.array(history["val_dice_coef"]).astype(np.float32)
            loss = np.array(history["loss"]).astype(np.float32)
            val_loss = np.array(history["val_loss"]).astype(np.float32)
            
            axes[0,0].plot(dice_coef, label = f"{VER} f: {i}")
            axes[0,1].plot(val_dice_coef, label = f"{VER} f: {i}")
            axes[1,0].plot(loss, label = f"{VER} f: {i}")
            axes[1,1].plot(val_loss, label = f"{VER} f: {i}")
            
            axes[0,0].legend()
            axes[0,0].set_title("dice_coef")
            axes[0,1].set_title("val_dice_coef")
            axes[1,0].set_title("loss")
            axes[1,1].set_title("val_loss")
            
            i += 1
    plt.show()

# %%
plot_vers([160, 161, 162, 163])
